# %% [markdown]
# # DATA ANALYSIS OF A TITANIC DATA SET (.csv)

# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#Thank you

# %%
import numpy as np
k=({
    'a':[12,23,34,45],
    'b':[56,67,np.nan,np.nan],
    'c':[90,np.nan,34,45],
    'd':[612,523,np.nan,745]
})
df=pd.DataFrame(k)
df
# Out:
#     a     b     c      d
# 0  12  56.0  90.0  612.0
# 1  23  67.0   NaN  523.0
# 2  34   NaN  34.0    NaN
# 3  45   NaN  45.0  745.0

# %%
df['b'].isnull().sum()
# Out:
# 2

# %%
df.b.ffill(inplace=True)

# %%
df
# Out:
#     a     b     c      d
# 0  12  56.0  90.0  612.0
# 1  23  67.0   NaN  523.0
# 2  34  67.0  34.0    NaN
# 3  45  67.0  45.0  745.0

# %%
df.c.bfill,df.d.ffill(inplace=True)
# Out:
# (<bound method NDFrame.bfill of 0    90.0
#  1     NaN
#  2    34.0
#  3    45.0
#  Name: c, dtype: float64>, None)

# %%
df
# Out:
#     a     b     c      d
# 0  12  56.0  90.0  612.0
# 1  23  67.0   NaN  523.0
# 2  34  67.0  34.0  523.0
# 3  45  67.0  45.0  745.0

# %%
df.mean()
# Out:
# a     28.500000
# b     64.250000
# c     56.333333
# d    600.750000
# dtype: float64

# %% [markdown]
# # Load my .csv file...

# %%
titanic_train= pd.read_csv(r'train.csv')
titanic_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# # in order to see the null value in data set

# %%
sns.heatmap(titanic_train.isnull(),yticklabels=False)

# %% [markdown]
# # clearing my data

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean_age=titanic_train['Age'].mean()

# %%
titanic_train['Age'].fillna(int(mean_age),inplace=True)

# %%
titanic_train.Cabin.bfill(inplace=True)

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       2
# dtype: int64

# %%
titanic_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  29.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   C85        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C123        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   E46        S
# 5      0            330877   8.4583   E46        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750    G6        S
# 8      2            347742  11.1333    G6        S
# 9      0            237736  30.0708    G6        C

# %%
sns.heatmap(titanic_train.isnull(),yticklabels=False,cmap='rainbow')

# %% [markdown]
# # Analysis start....

# %%
titanic_train.hist(bins=50,figsize=(10,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a171db5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1730dc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1734c278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1737b828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a173b0dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a173e93c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1741a978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1744df60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1744df98>]],
#       dtype=object)

# %%
sns.distplot(titanic_train['Survived'],hist=False)

# %%
sns.countplot(x='Survived',hue='Sex', data=titanic_train)

# %%
sns.scatterplot(y='Survived',x='Age',hue='Sex',data=titanic_train)

# %%
sns.set_style(style='darkgrid')
sns.scatterplot(y='Fare',x='Age',hue='Sex',data=titanic_train)

# %%
sns.set_style(style='darkgrid')
sns.regplot(y='Fare',x='Age',data=titanic_train)

# %%
sns.relplot(y='Fare',x='Age',kind='line',data=titanic_train)

# %%
sns.relplot(x='Survived',y='Age',kind='line',data=titanic_train)

# %% [markdown]
# # combined my all relevent plot

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,3,1)
sns.set_style(style='darkgrid')
sns.countplot(x='Survived',hue='Sex', data=titanic_train)

plt.subplot(3,3,2)
sns.scatterplot(y='Survived',x='Age',hue='Sex',data=titanic_train)

plt.subplot(3,3,3)
sns.scatterplot(y='Fare',x='Age',hue='Sex',data=titanic_train)

plt.subplot(3,3,4)
sns.regplot(y='Fare',x='Age',data=titanic_train)

plt.subplot(3,3,5)
sns.relplot(y='Fare',x='Age',kind='line',data=titanic_train)

# %%
sns.jointplot(y='Fare',x='Age',kind='kde',data=titanic_train)

# %%
sns.jointplot(y='Fare',x='Age',kind="resid",data=titanic_train)

# %%
sns.jointplot(y='Fare',x='Age',kind="scatter",data=titanic_train)

# %%
sns.jointplot(y='Fare',x='Age',kind="reg",data=titanic_train)

# %%
titanic_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  29.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   C85        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C123        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   E46        S
# 5      0            330877   8.4583   E46        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750    G6        S
# 8      2            347742  11.1333    G6        S
# 9      0            237736  30.0708    G6        C

# %% [markdown]
# # to analyse only age of a person

# %%
age1=titanic_train.loc[(titanic_train['Age']>=0) & (titanic_train['Age']<15) ,'Age']
a=len(age1)
print(f'Age between (0 to 14)-:{a}')

age2=titanic_train.loc[(titanic_train['Age']>=15) & (titanic_train['Age']<30) ,'Age']
b=len(age2)
print(f'Age between (15 to 29)-:{b}')

age3=titanic_train.loc[(titanic_train['Age']>=30) & (titanic_train['Age']<45) ,'Age']
c=len(age3)
print(f'Age between (30 to 44)-:{c}')

age4=titanic_train.loc[(titanic_train['Age']>=45) & (titanic_train['Age']<60) ,'Age']
d=len(age4)
print(f'Age between (45 to 59)-:{d}')

age5=titanic_train.loc[(titanic_train['Age']>=60) & (titanic_train['Age']<75) ,'Age']
e=len(age5)
print(f'Age between (60 to 74)-:{e}')

age6=titanic_train.loc[titanic_train['Age']>=75,'Age']
f=len(age6)
print(f'Age above 75+ -:{f}')
# Out:
# Age between (0 to 14)-:78
# Age between (15 to 29)-:483
# Age between (30 to 44)-:215
# Age between (45 to 59)-:89
# Age between (60 to 74)-:25
# Age above 75+ -:1

# %%
agegrp=[a,b,c,d,e,f]
label=['Age(0 to 14)','Age(15 to 29)',
       'Age(30 to 44)','Age(45 to 59)','Age(60 to 74)',
      'Age(above75)']
def bar_plotting_x():
    index=np.arange(len(label))
    plt.bar(index,agegrp)
    plt.ylabel('age group of people', fontsize=9)
    plt.xticks(index,label,fontsize=10,rotation=20)
    plt.show()
    
bar_plotting_x()

# %%
sns.distplot(agegrp,bins=10)

# %% [markdown]
# # full_specification of a particular passenger unique Id

# %%
def full_specification():
    while True:   
        enquiry=int(input('enter Passenger Unique ID-:'))

        if enquiry in titanic_train.PassengerId:
            a1=titanic_train.iloc[enquiry-1]['PassengerId']
            a2=titanic_train.iloc[enquiry-1]['Name']
            a3=titanic_train.iloc[enquiry-1]['Sex']
            a4=titanic_train.iloc[enquiry-1]['Age']
            a5=titanic_train.iloc[enquiry-1]['Ticket'],titanic_train.iloc[enquiry-1]['Fare']
            a6=titanic_train.iloc[enquiry-1]['Cabin']
            print(f'Enquiry for passenger Unique Id-->{a1}\nName-->{a2}\nGender-->{a3}\nAge-->{a4}\nCabin-->{a6}\nFare and ticket-->{a5}')
            print("*****************************************************************************************************************")
        elif enquiry not in titanic_train.PassengerId:
            print('SEEMS TO BE ENTERED A WRONG PASSENGER UNIQUE ID')
            break
            
full_specification()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# //anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# //anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# //anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-6bfa405b2c4f> in <module>
#      16             break
#      17
# ---> 18 full_specification()
#
# <ipython-input-35-6bfa405b2c4f> in full_specification()
#       1 def full_specification():
#       2     while True:
# ----> 3         enquiry=int(input('enter Passenger Unique ID-:'))
#       4
#       5         if enquiry in titanic_train.PassengerId:
#
# //anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# //anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     888             except KeyboardInterrupt:
#     889                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 890                 raise KeyboardInterrupt
#     891             else:
#     892                 break
#
# KeyboardInterrupt:

# %%
def box_plotting2():
    name=[n for n in titanic_train.Name.head(20)]
    fare=[f for f in titanic_train.Fare.head(20)]
    index=np.arange(len(name))
    plt.figure(figsize=(10,15))
    plt.subplot(2,2,1)
    plt.boxplot(index,fare)
    plt.subplot(2,2,2)
    plt.barh(index,fare)
    plt.subplot(2,2,3)
    plt.plot(index,fare)
    plt.xlabel('fare of titanic voyage',fontsize=12)
    plt.yticks(index,name,fontsize=10)
    plt.show()
    
box_plotting2()
