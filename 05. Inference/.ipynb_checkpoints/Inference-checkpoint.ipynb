# %% [markdown]
# # Data  Inference

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import pandas as pd
data_path = 'data.csv'
mydf = pd.read_csv(data_path, names=["sales_per_day","customers_per_day"], sep=';')

# %%
mydf
# Out:
#                                                                     sales_per_day  \
# brand      country     currency customers_per_day outlet_id week_id       weekday
# MediaMarkt spain       EURO     3138.0            100.0     34.0              sat
# Saturn     germany     EURO     378.0             86.0      8.0               mon
# MediaMarkt italy       EURO     379.0             530.0     28.0              thu
# Saturn     germany     EURO     3050.0            17.0      47.0              sat
# MediaMarkt spain       EURO     548.0             164.0     7.0               tue
#            austria     EURO     1424.0            399.0     7.0               fri
#            italy       EURO     479.0             598.0     46.0              thu
#            austria     EURO     2028.0            342.0     36.0              sat
#            germany     EURO     1425.0            56.0      46.0              fri
# ...

# %%
mydf.sales_per_day.value_counts()
# Out:
# thu        2598
# tue        2597
# mon        2597
# wed        2597
# fri        2594
# sun        2594
# sat        2593
# weekday       1
# Name: sales_per_day, dtype: int64

# %% [markdown]
# # Testing hypotheses and deriving estimates
#     1. Null hypothesis (H0)
#     2. Alternative hypothesis (H1)
#     Population, Intervention, Comparison, Outcome, Time = PICOT

# %%
import random
import numpy as np
from scipy import *

np.random.choice(1, size=10, replace=True, p=None)
print(random)
# Out:
# <module 'numpy.random' from '/Users/robert/anaconda3/lib/python3.7/site-packages/numpy/random/__init__.py'>
