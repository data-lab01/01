# %% [markdown]
# # Data Exploration
#
# Short explanation of the dataset:
# - __outlet_id__: The ID of a outlet/market
# - __country__: The country in which the outlet is located
# - __brand__: "MediaMarkt" or "Saturn"
# - __customers_per_day__: The number of customers per day in this outlet
# - __sales_per_day__: The amount of sales for a specific outlet on a specific day
# - __currency__: The currency of __sales_per_day__
# - __week_id__: Calendar week
# - __weekday__: mon = Monday, tue = Tuesday, ... , sun = Sunday
#
# I also need to partition the data set into three parts (training, validation and testing data sets)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

data_path = 'data.csv'
mydf = pd.read_csv(data_path, sep=';')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mydf.head()
# Out:
#         brand  country currency  customers_per_day  outlet_id  week_id  \
# 0  MediaMarkt    spain     EURO             3138.0      100.0     34.0
# 1      Saturn  germany     EURO              378.0       86.0      8.0
# 2  MediaMarkt    italy     EURO              379.0      530.0     28.0
# 3      Saturn  germany     EURO             3050.0       17.0     47.0
# 4  MediaMarkt    spain     EURO              548.0      164.0      7.0
#
#   weekday  sales_per_day
# 0     sat       72169.14
# 1     mon       52825.62
# 2     thu       53309.83
# 3     sat       74237.45
# 4     tue       56621.61

# %%
mean1 = mydf['customers_per_day'].mean()
mean2 = mydf['sales_per_day'].mean()
sum = mydf.groupby('country')[['sales_per_day']].sum()
max = mydf['sales_per_day'].max()
count = mydf['sales_per_day'].count()
median = mydf['sales_per_day'].median()
variance = mydf['sales_per_day'].var()
std = mydf['sales_per_day'].std()
uniqueness = mydf['week_id'].unique()

# %%
mean1,mean2,sum,max,count,uniqueness
# Out:
# (259.3515028298258, 50823.37805914351,              sales_per_day
#  country
#  austria       1.265447e+08
#  germany       2.531227e+08
#  greece        1.101990e+08
#  italy         1.455911e+08
#  netherlands   1.068689e+08
#  spain         1.251726e+08
#  switzerland   5.604940e+07, 96225.53, 18193, array([ 3.40000e+01,  8.00000e+00,  2.80000e+01,  4.70000e+01,
#          7.00000e+00,  4.60000e+01,  3.60000e+01,  1.00000e+01,
#          4.90000e+01,  5.10000e+01,  2.00000e+01,  4.80000e+01,
#          4.00000e+01,  4.40000e+01,  1.20000e+01,  3.20000e+01,
#          2.60000e+01,  4.50000e+01,  4.00000e+00,  3.50000e+01,
#          1.50000e+01,  2.90000e+01,  4.10000e+01,  2.70000e+01,
#          5.00000e+00,  9.00000e+00,  3.80000e+01,  2.50000e+01,
#          2.10000e+01,  3.70000e+01,  4.30000e+01,  3.10000e+01,
#          1.10000e+01,  3.30000e+01,  2.30000e+01,  3.90000e+01,
#          2.40000e+01,  1.40000e+01,  3.00000e+00,  1.80000e+01,
#          1.90000e+01,  6.00000e+00,  1.70000e+01,  5.00000e+01,
#          1.60000e+01,  4.20000e+01,  1.30000e+01,  5.20000e+01,
#          3.00000e+01,  2.00000e+00,  2.20000e+01,  1.00000e+00,
#                  nan, -9.99999e+05]))

# %%
mydf.columns
# Out:
# Index(['brand', 'country', 'currency', 'customers_per_day', 'outlet_id',
#        'week_id', 'weekday', 'sales_per_day'],
#       dtype='object')

# %%
data_path = 'data.csv'
mydf = pd.read_csv(data_path, sep=';')

sns.countplot(mydf['country']);

# %%
sns.scatterplot(x=mydf['week_id'], y=mydf['country']);

# %%
#The categorical variables analysis for our dataframe
    
fig, z = plt.pyplot.subplots(2, 4, figsize=(20, 10))
for variable, subplot in zip(mydf, z.flatten()):
    sns.countplot(mydf[variable], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# Germany makes alot of sales with mediamarkt brand in Euros, and mostly in saturdays.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6)
sns.boxplot(data=mydf);

# %%
sns.regplot(y = 'sales_per_day', x = 'customers_per_day', data = mydf, color = 'green')

# %% [markdown]
# Features

# %%
print(mydf.select_dtypes(include=['object']).columns.values)
# Out:
# ['brand' 'country' 'currency' 'weekday']

# %%
sns.catplot('brand', 'sales_per_day', data = mydf, color = 'r', \
               estimator = np.median, height = 4.5,  aspect=1.35)

# %%
mydf.head()
# Out:
#         brand  country currency  customers_per_day  outlet_id  week_id  \
# 0  MediaMarkt    spain     EURO             3138.0      100.0     34.0
# 1      Saturn  germany     EURO              378.0       86.0      8.0
# 2  MediaMarkt    italy     EURO              379.0      530.0     28.0
# 3      Saturn  germany     EURO             3050.0       17.0     47.0
# 4  MediaMarkt    spain     EURO              548.0      164.0      7.0
#
#   weekday  sales_per_day
# 0     sat       72169.14
# 1     mon       52825.62
# 2     thu       53309.83
# 3     sat       74237.45
# 4     tue       56621.61
